# %%
import lib.spectrum_single_bin as spec
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import lib.spectrum_single_bin as spec
#       2 import numpy as np
#
# File /workspaces/D-and-B-decay-bounds-FASER-CHARM/lib/spectrum_single_bin.py:3
#       1 ### HEADER
#       2 import numpy as np
# ----> 3 import kinematics as kin
#       5 ### Constants ###
#       7 mB0, mK0, mD0, mPi0 = np.array([5279.65, 497.611, 1864.84, 134.976])* 10**(-3) # Meson masses in GeV;
#
# ModuleNotFoundError: No module named 'kinematics'

# %%
kin.
